# %% [markdown]
# # Анализ множественных прогонов нейросети для модели Крюков-Шолохов

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

# %run main_serv.py
auth_load=authors.copy()

# %% [markdown]
# ## Filter result files (jnly selected authors)

# %%
auth_load.use(val=False)
auth_load.use(index=['sera', 'fad', 'kru', 'sho']) # load these authors

work_list=auth_load.loc[auth_load['in_use'], 'strFileDir'].tolist()

csvs=[fl for fl in glob.glob('*.csv') if re.search('result_prob_', fl)]
work_au=[re.search('result_prob_(\w+).csv', auth).group(1) for auth in csvs]
work_dict=dict(zip(work_au, csvs))
work_dict=dict(filter(lambda x: x[0] in work_list, work_dict.items()))
print(work_dict)
# Out:
# not found param key_word "index" so set value to ALL authors
# {'Serafimovich': 'result_prob_Serafimovich.csv', 'Sholokhov': 'result_prob_Sholokhov.csv', 'Fadeyev': 'result_prob_Fadeyev.csv', 'Krukov': 'result_prob_Krukov.csv'}

# %% [markdown]
# ## Load and prepare data
#
# "Среднее выборок приблизительно равно среднему популяции" - в каждом результирующем файле по каждомуавторурезультат 13-циклов обучение-классификация нейросети, считаем среднее по главам, смотрим всякую статистику

# %%
dict_pdf={k:pd.read_csv(v, sep=';') for k, v in work_dict.items()}

prob_cols=[c for c in dict_pdf[work_au[0]].columns.tolist() if re.search('(?i)prob', c)]
plot_list=[]
for k, v in dict_pdf.items():
    print(k, v.shape)
    v[k]=v.mean(axis=1)
    draw_cols=[c for c in v.columns.tolist() if not re.search('(?i)prob', c)]
    plot_list.append(v[draw_cols].set_index(['name', 'short_text']))
# Out:
# Serafimovich (169, 15)
# Sholokhov (169, 15)
# Fadeyev (169, 15)
# Krukov (169, 15)

# %%
pdf_result=plot_list[0].join(plot_list[1:])

pdf_result.boxplot();
pdf_result.describe()
# Out:
#        Serafimovich   Sholokhov     Fadeyev      Krukov
# count    169.000000  169.000000  169.000000  169.000000
# mean       0.026864    0.157991    0.067202    0.114027
# std        0.025314    0.104287    0.057185    0.110950
# min        0.000866    0.009835    0.001300    0.014815
# 25%        0.010009    0.078283    0.027960    0.050537
# 50%        0.018372    0.141638    0.046147    0.081158
# 75%        0.036441    0.213428    0.092700    0.124827
# max        0.165934    0.547769    0.323707    0.813601

# %%
pdf_kru=dict_pdf['Krukov']
pdf_kru.loc[pdf_kru['Krukov']>0.4]
# Out:
#            name                                         short_text   prob2_0  \
# 80   b2_p11_h11  Назначение генерала Корнилова главнокомандующи...  0.527486
# 83   b2_p14_h14  За день до приезда Корнилова в Москву есаул Ли...  0.411033
# 89   b2_p20_h20  Теплилась осень. Перепадали дожди. Над Быховом...  0.471551
# 101    b3_p1_h1  Как ты, батюшка, славный тихий Дон,\nТы кормил...  0.446648
# 104    b3_p4_h4  15 мая атаман Всевеликого войска Донского Крас...  0.898870
# 111  b3_p11_h11  В конце ноября в Новочеркасске стало известно ...  0.771578
# 162  b4_p23_h23  17 сентября части ударной группы Шорина, сдела...  0.461202
#
#       prob2_1   prob2_2   prob2_3   prob2_4   prob2_5   prob2_6   prob2_7  \
# 80   0.356939  0.591674  0.512923  0.464892  0.466918  0.436118  0.532895
# 83   0.338450  0.485441  0.431288  0.378906  0.404897  0.423586  0.465018
# 89   0.355559  0.519338  0.415137  0.474751  0.470934  0.521410  0.433225
# 101  0.350436  0.458255  0.397412  0.374398  0.430136  0.413649  0.479067
# 104  0.671169  0.900062  0.855200  0.766042  0.903359  0.827207  0.749400
# 111  0.569347  0.742890  0.707478  0.608468  0.721260  0.744122  0.722720
# 162  0.325624  0.507226  0.381701  0.374342  0.372252  0.491333  0.485611
#
#       prob2_8   prob2_9  prob2_10  prob2_11  prob2_12    Krukov
# 80   0.473786  0.432185  0.480779  0.462059  0.570955  0.485354
# 83   0.315547  0.400673  0.362453  0.406276  0.491181  0.408827
# 89   0.413060  0.437031  0.483308  0.413537  0.452569  0.450878
# 101  0.510497  0.340107  0.458197  0.476600  0.440276  0.428898
# 104  0.718062  0.782134  0.819736  0.843860  0.841714  0.813601
# 111  0.607193  0.678558  0.673195  0.678455  0.726189  0.688573
# 162  0.327836  0.418953  0.447284  0.495170  0.484321  0.428681

# %%
pdf_fad=dict_pdf['Fadeyev']
pdf_fad.loc[pdf_fad['Fadeyev']>0.2]
# Out:
#            name                                         short_text   prob2_0  \
# 7      b1_p1_h8  За два дня до троицы хуторские делили луг. На ...  0.203772
# 41    b1_p2_h19  Степан подошел к Григорию и, ухватившись за ст...  0.239888
# 101    b3_p1_h1  Как ты, батюшка, славный тихий Дон,\nТы кормил...  0.283456
# 126  b3_p26_h26  Григория заставили из Боковской ехать в Черныш...  0.286574
# 129  b3_p29_h29  На рассвете, измученный, Кошевой въехал в хуто...  0.325916
#
#       prob2_1   prob2_2   prob2_3   prob2_4   prob2_5   prob2_6   prob2_7  \
# 7    0.207086  0.194547  0.209054  0.209096  0.173423  0.237619  0.264854
# 41   0.247875  0.204043  0.244314  0.258590  0.199599  0.222217  0.354081
# 101  0.256116  0.341121  0.295019  0.252640  0.232090  0.326331  0.404385
# 126  0.217902  0.239677  0.278157  0.225794  0.188601  0.251582  0.304552
# 129  0.301814  0.367126  0.277934  0.241309  0.346365  0.287536  0.426522
#
#       prob2_8   prob2_9  prob2_10  prob2_11  prob2_12   Fadeyev
# 7    0.195333  0.249728  0.169143  0.330384  0.193880  0.218301
# 41   0.237196  0.238822  0.170907  0.310784  0.214437  0.241750
# 101  0.282441  0.273158  0.211645  0.340692  0.244805  0.287992
# 126  0.245628  0.231044  0.187218  0.308104  0.206954  0.243984
# 129  0.373560  0.321370  0.221936  0.378952  0.337856  0.323707

# %%
pdf_sho=dict_pdf['Sholokhov']
pdf_sho.loc[pdf_sho['Sholokhov']>0.4]
# Out:
#            name                                         short_text   prob2_0  \
# 14    b1_p1_h15  — Петру скажи, чтобы запрягал кобылу и своего ...  0.614266
# 34    b1_p2_h12  Аксинья отстряпалась рано, загребла жар, закут...  0.610321
# 155  b4_p16_h16  Несколько дней после разговора с Дарьей Наталь...  0.467056
# 156  b4_p17_h17  Многое передумал и вспомнил Григорий за двое с...  0.536137
# 164  b4_p25_h25  Через месяц Григорий выздоровел. Впервые подня...  0.635633
# 165  b4_p26_h26  — Ну, война кончилась! Пихнули нас красные так...  0.508216
#
#       prob2_1   prob2_2   prob2_3   prob2_4   prob2_5   prob2_6   prob2_7  \
# 14   0.490730  0.403546  0.470963  0.384957  0.465653  0.431960  0.427058
# 34   0.553163  0.542134  0.472967  0.417478  0.490582  0.444851  0.561628
# 155  0.559851  0.457466  0.513765  0.324330  0.426958  0.382425  0.496390
# 156  0.599003  0.473673  0.530914  0.449755  0.474343  0.453632  0.547117
# 164  0.622288  0.574480  0.603082  0.418260  0.580826  0.493157  0.631873
# 165  0.454653  0.486928  0.426935  0.287456  0.392020  0.341867  0.516751
#
#       prob2_8   prob2_9  prob2_10  prob2_11  prob2_12  Sholokhov
# 14   0.458583  0.415023  0.319366  0.380135  0.393031   0.435021
# 34   0.524563  0.466075  0.411722  0.471214  0.480079   0.495906
# 155  0.470820  0.447746  0.384878  0.398282  0.407974   0.441380
# 156  0.529857  0.582842  0.351714  0.473253  0.401842   0.492622
# 164  0.596356  0.556413  0.417478  0.532137  0.459010   0.547769
# 165  0.426353  0.405413  0.272532  0.377251  0.318105   0.401114
