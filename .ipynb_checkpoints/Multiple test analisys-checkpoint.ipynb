# %% [markdown]
# # Анализ множественных прогонов нейросети для модели Крюков-Шолохов

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import glob
import os

# %matplotlib inline

# %run main_serv.py
auth_load=authors.copy()

# %% [markdown]
# ## Filter result files (jnly selected authors)

# %%
res_list=['result/lt1', 'result/f1', 'result/ga1', 'result/ilf1', 'result/ka1', 'result/mm', 'result/o1',
         'result/pa1', 'result/pl1', 'result/TD']
strResultDir=res_list[8]

#auth_load.use(val=False)
#auth_load.use(index=['sera', 'fad', 'kru', 'sho', 'ltol', 'kat', 'pla']) # load these authors

work_list=auth_load.loc[auth_load['in_use'], 'strFileDir'].tolist()

csvs=[fl for fl in glob.glob(os.path.join(strResultDir,'*.csv')) if re.search('result_prob_', fl)]
work_au=[re.search('result_prob_(\w+).csv', auth).group(1) for auth in csvs]
work_dict=dict(zip(work_au, csvs))
work_dict=dict(filter(lambda x: x[0] in work_list, work_dict.items()))
print(work_dict)
# Out:
# {}

# %% [markdown]
# ## Load and prepare data
#
# "Среднее выборок приблизительно равно среднему популяции" - в каждом результирующем файле по каждомуавторурезультат 13-циклов обучение-классификация нейросети, считаем среднее по главам, смотрим всякую статистику

# %%
dict_pdf={k:pd.read_csv(v, sep=';') for k, v in work_dict.items()}

prob_cols=[c for c in dict_pdf[work_au[0]].columns.tolist() if re.search('(?i)prob', c)]
plot_list=[]
for k, v in dict_pdf.items():
    print(k, v.shape)
    v[k]=v.mean(axis=1)
    draw_cols=[c for c in v.columns.tolist() if not re.search('(?i)prob', c)]
    plot_list.append(v[draw_cols].set_index(['name', 'short_text']))
# Out:
# Babel (230, 3)
# Serafimovich (230, 3)
# Tolstoy (230, 3)
# Platonov (230, 3)
# Sholokhov (230, 3)
# Fadeyev (230, 3)
# Bulgakov (230, 3)
# Kataev (230, 3)
# Krukov (230, 3)

# %%
fig, ax=plt.subplots()

pdf_result=plot_list[0].join(plot_list[1:])

box=pdf_result.boxplot(rot=90, ax=ax);
#ax.margins(y=0.05)
ax.set_ylim([0,1.05])
plt.show();
pdf_result.describe()
# Out:
#             Babel  Serafimovich     Tolstoy    Platonov   Sholokhov  \
# count  230.000000    230.000000  230.000000  230.000000  230.000000
# mean     0.003283      0.001380    0.015305    0.026940    0.002372
# std      0.005044      0.002953    0.033791    0.044059    0.004281
# min      0.000189      0.000083    0.000120    0.000320    0.000231
# 25%      0.000593      0.000248    0.001245    0.004091    0.000688
# 50%      0.001264      0.000532    0.004083    0.008783    0.001251
# 75%      0.003470      0.001211    0.014921    0.031926    0.002237
# max      0.037811      0.034582    0.268237    0.391900    0.050820
#
#           Fadeyev    Bulgakov      Kataev      Krukov
# count  230.000000  230.000000  230.000000  230.000000
# mean     0.002151    0.011393    0.005040    0.027599
# std      0.003676    0.022110    0.007854    0.049792
# min      0.000119    0.000220    0.000303    0.000947
# 25%      0.000445    0.001475    0.000922    0.005563
# 50%      0.000861    0.003913    0.002038    0.010253
# 75%      0.002108    0.010123    0.005058    0.028262
# max      0.026360    0.163085    0.044274    0.474597

# %%
ax=pdf_result[['Krukov', 'Sholokhov']].plot.scatter(x='Krukov', y='Sholokhov')

# %%
pdf_result['Serafimovich'].idxmax()
# Out:
# ('Последний из удэге_112', nan)

# %%
pdf_fad=dict_pdf['Fadeyev']
pdf_fad.loc[pdf_fad['Fadeyev']>0.2]
# Out:
#                        name  \
# 2     Последний из удэге_70
# 3    Последний из удэге_140
# 17     Последний из удэге_5
# 32    Последний из удэге_60
# 33    Последний из удэге_63
# 35   Последний из удэге_109
# 36     Последний из удэге_4
# 37            Один в чаще_2
# 39          Землетрясение_1
# 41    Последний из удэге_59
# 51    Последний из удэге_77
# 57   Последний из удэге_141
# 58   Последний из удэге_135
# 64          Землетрясение_3
# 76   Последний из удэге_118
# 83    Последний из удэге_57
# 84    Последний из удэге_50
# 88   Последний из удэге_112
# 89    Последний из удэге_72
# 91          Землетрясение_5
# 93          Землетрясение_4
# 96   Последний из удэге_119
# 103   Последний из удэге_71
# 104   Последний из удэге_42
# 108   Последний из удэге_94
# 111   Последний из удэге_73
# 114  Последний из удэге_138
# 115   Последний из удэге_89
# 116         Землетрясение_2
# 126           Один в чаще_3
# 136           Один в чаще_1
# 140   Последний из удэге_61
# 142  Последний из удэге_103
# 144   Последний из удэге_78
# 146   Последний из удэге_65
# 147  Последний из удэге_101
# 148   Последний из удэге_62
# 149   Последний из удэге_64
#
#                                             short_text   prob2_0   prob2_1  \
# 2    Умывшись в баньке, перекусив и надев чистую го...  0.273196  0.215644
# 3    Народ кочевал по стране, могущей вместить семь...  0.363914  0.372923
# 17   Под самой Ольгой, возле листвяного шалаша, еще...  0.429942  0.485126
# 32   Сеня впервые так близко столкнулся с хунхузами...  0.229984  0.220000
# 33   Было уже около полуночи; в тайге все стихло; п...  0.488209  0.521031
# 35   Отправив Петра с обозом раненых в Скобеевку, А...  0.267917  0.276226
# 36   Перевал далеко уже остался за их спиной, когда...  0.309282  0.329347
# 37   Утреннее, нарочито веселое настроение долго не...  0.116152  0.998649
# 39   В 1920 году по условиям перемирия, заключенног...  0.497233  0.333014
# 41   Отряд Гладких уже третий день продвигался по т...  0.470055  0.555000
# 51   - А теперь, товарищи дорогие, - торжественно в...  0.388982  0.502250
# 57   Впервые Масенда узнал сам себя в расшитом краш...  0.319730  0.308212
# 58   Пока подводы с подрывниками и фугасами добирал...  0.303203  0.304243
# 64   В долине, куда вышли Майгула и Шутка, стоял Су...  0.998024  0.584979
# 76   Они выехали на рудник верхами, а потом пошли п...  0.304223  0.275851
# 83   Открыв глаза, он несколько минут лежал со смут...  0.488550  0.519797
# 84   К полдню отряд вышел на речушку Сыдагоу. Гладк...  0.415461  0.316536
# 88                                                 NaN  0.795966  0.825131
# 89                                                 NaN  0.795966  0.825131
# 91   А наутро погиб Бархатный перевал. Майгула и ст...  0.999106  0.998724
# 93   Дорога, которую строил Шутка, проходила через ...  0.474969  0.343695
# 96   Чтобы повидать Суркова, Яков Бутов и товарищ е...  0.229372  0.294216
# 103                                                NaN  0.795966  0.825131
# 104                                                NaN  0.795966  0.825131
# 108  Обстоятельства занятия Шкотова партизанами был...  0.296493  0.393408
# 111  Алеша Маленький был послан в районы восстания ...  0.436850  0.379614
